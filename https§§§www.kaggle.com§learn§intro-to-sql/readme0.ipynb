# %%
# %pip install google-cloud-bigquery
# Out:
# Requirement already satisfied: google-cloud-bigquery in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (3.25.0)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.7.1)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.4.1)
# Requirement already satisfied: packaging>=20.0.0 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-cloud-bigquery) (24.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.19.0)
# Requirement already satisfied: requests<3.0.0dev,>=2.21.0 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.32.3)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.9.0.post0)
# Requirement already satisfied: google-auth<3.0.0dev,>=2.14.1 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-cloud-bigquery) (2.30.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (1.24.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0.dev0,>=3.19.5 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (4.25.3)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (1.63.1)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (1.62.2)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-cloud-bigquery) (1.64.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (0.4.0)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from google-resumable-media<3.0dev,>=0.6.0->google-cloud-bigquery) (1.5.0)
# Requirement already satisfied: six>=1.5 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (2024.6.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from requests<3.0.0dev,>=2.21.0->google-cloud-bigquery) (3.7)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in ./https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0dev,>=2.14.1->google-cloud-bigquery) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ![image.png](./image-1.png)

# %%
from google.cloud import bigquery
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "./https§§§www.kaggle.com§learn§intro-to-sql/sa.json"


# Create a "Client" object
client = bigquery.Client()

# Construct a reference to the "hacker_news" dataset
dataset_ref = client.dataset("hacker_news", project="bigquery-public-data")

# API request - fetch the dataset
dataset = client.get_dataset(dataset_ref)
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# Cell In[15], line 13
#      10 dataset_ref = client.dataset("chicago_crime", project="bigquery-public-data")
#      12 # API request - fetch the dataset
# ---> 13 dataset = client.get_dataset(dataset_ref)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/cloud/bigquery/client.py:870, in Client.get_dataset(self, dataset_ref, retry, timeout)
#     868 path = dataset_ref.path
#     869 span_attributes = {"path": path}
# --> 870 api_response = self._call_api(
#     871     retry,
#     872     span_name="BigQuery.getDataset",
#     873     span_attributes=span_attributes,
#     874     method="GET",
#     875     path=path,
#     876     timeout=timeout,
#     877 )
#     878 return Dataset.from_api_repr(api_response)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/cloud/bigquery/client.py:833, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     829 if span_name is not None:
#     830     with create_span(
#     831         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     832     ):
# --> 833         return call()
#     835 return call()
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/auth/transport/requests.py:534, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     531 remaining_time = max_allowed_time
#     533 with TimeoutGuard(remaining_time) as guard:
# --> 534     self.credentials.before_request(auth_request, method, url, request_headers)
#     535 remaining_time = guard.remaining_timeout
#     537 with TimeoutGuard(remaining_time) as guard:
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/auth/credentials.py:230, in Credentials.before_request(self, request, method, url, headers)
#     228     self._non_blocking_refresh(request)
#     229 else:
# --> 230     self._blocking_refresh(request)
#     232 metrics.add_metric_header(headers, self._metric_header_for_usage())
#     233 self.apply(headers)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/auth/credentials.py:193, in Credentials._blocking_refresh(self, request)
#     191 def _blocking_refresh(self, request):
#     192     if not self.valid:
# --> 193         self.refresh(request)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/oauth2/service_account.py:446, in Credentials.refresh(self, request)
#     444 else:
#     445     assertion = self._make_authorization_grant_assertion()
# --> 446     access_token, expiry, _ = _client.jwt_grant(
#     447         request, self._token_uri, assertion
#     448     )
#     449     self.token = access_token
#     450     self.expiry = expiry
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/oauth2/_client.py:304, in jwt_grant(request, token_uri, assertion, can_retry)
#     280 """Implements the JWT Profile for OAuth 2.0 Authorization Grants.
#     281
#     282 For more details, see `rfc7523 section 4`_.
#    (...)
#     300 .. _rfc7523 section 4: https://tools.ietf.org/html/rfc7523#section-4
#     301 """
#     302 body = {"assertion": assertion, "grant_type": _JWT_GRANT_TYPE}
# --> 304 response_data = _token_endpoint_request(
#     305     request,
#     306     token_uri,
#     307     body,
#     308     can_retry=can_retry,
#     309     headers={
#     310         metrics.API_CLIENT_HEADER: metrics.token_request_access_token_sa_assertion()
#     311     },
#     312 )
#     314 try:
#     315     access_token = response_data["access_token"]
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/oauth2/_client.py:275, in _token_endpoint_request(request, token_uri, body, access_token, use_json, can_retry, headers, **kwargs)
#     264 response_status_ok, response_data, retryable_error = _token_endpoint_request_no_throw(
#     265     request,
#     266     token_uri,
#    (...)
#     272     **kwargs
#     273 )
#     274 if not response_status_ok:
# --> 275     _handle_error_response(response_data, retryable_error)
#     276 return response_data
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/oauth2/_client.py:68, in _handle_error_response(response_data, retryable_error)
#      65 except (KeyError, ValueError):
#      66     error_details = json.dumps(response_data)
# ---> 68 raise exceptions.RefreshError(
#      69     error_details, response_data, retryable=retryable_error
#      70 )
#
# RefreshError: ('invalid_grant: Invalid JWT: Token must be a short-lived token (60 minutes) and in a reasonable timeframe. Check your iat and exp values in the JWT claim.', {'error': 'invalid_grant', 'error_description': 'Invalid JWT: Token must be a short-lived token (60 minutes) and in a reasonable timeframe. Check your iat and exp values in the JWT claim.'})

# %%
# List all the tables in the "hacker_news" dataset
tables = list(client.list_tables(dataset))

# Print names of all tables in the dataset (there are four!)
for table in tables:  
    print(table.table_id)
# Out:
# ---------------------------------------------------------------------------
# RefreshError                              Traceback (most recent call last)
# Cell In[25], line 2
#       1 # List all the tables in the "hacker_news" dataset
# ----> 2 tables = list(client.list_tables(dataset))
#       4 # Print names of all tables in the dataset (there are four!)
#       5 for table in tables:
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/page_iterator.py:208, in Iterator._items_iter(self)
#     206 def _items_iter(self):
#     207     """Iterator for each item returned."""
# --> 208     for page in self._page_iter(increment=False):
#     209         for item in page:
#     210             self.num_results += 1
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/page_iterator.py:244, in Iterator._page_iter(self, increment)
#     232 def _page_iter(self, increment):
#     233     """Generator of pages of API responses.
#     234
#     235     Args:
#    (...)
#     242         Page: each page of items from the API.
#     243     """
# --> 244     page = self._next_page()
#     245     while page is not None:
#     246         self.page_number += 1
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/page_iterator.py:373, in HTTPIterator._next_page(self)
#     366 """Get the next page in the iterator.
#     367
#     368 Returns:
#     369     Optional[Page]: The next page in the iterator or :data:`None` if
#     370         there are no pages left.
#     371 """
#     372 if self._has_next_page():
# --> 373     response = self._get_next_page_response()
#     374     items = response.get(self._items_key, ())
#     375     page = Page(self, items, self.item_to_value, raw_page=response)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/page_iterator.py:432, in HTTPIterator._get_next_page_response(self)
#     430 params = self._get_query_params()
#     431 if self._HTTP_METHOD == "GET":
# --> 432     return self.api_request(
#     433         method=self._HTTP_METHOD, path=self.path, query_params=params
#     434     )
#     435 elif self._HTTP_METHOD == "POST":
#     436     return self.api_request(
#     437         method=self._HTTP_METHOD, path=self.path, data=params
#     438     )
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/cloud/bigquery/client.py:1651, in Client.list_tables.<locals>.api_request(*args, **kwargs)
#    1650 def api_request(*args, **kwargs):
# -> 1651     return self._call_api(
#    1652         retry,
#    1653         span_name="BigQuery.listTables",
#    1654         span_attributes=span_attributes,
#    1655         *args,
#    1656         timeout=timeout,
#    1657         **kwargs,
#    1658     )
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/cloud/bigquery/client.py:833, in Client._call_api(self, retry, span_name, span_attributes, job_ref, headers, **kwargs)
#     829 if span_name is not None:
#     830     with create_span(
#     831         name=span_name, attributes=span_attributes, client=self, job_ref=job_ref
#     832     ):
# --> 833         return call()
#     835 return call()
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:293, in Retry.__call__.<locals>.retry_wrapped_func(*args, **kwargs)
#     289 target = functools.partial(func, *args, **kwargs)
#     290 sleep_generator = exponential_sleep_generator(
#     291     self._initial, self._maximum, multiplier=self._multiplier
#     292 )
# --> 293 return retry_target(
#     294     target,
#     295     self._predicate,
#     296     sleep_generator,
#     297     timeout=self._timeout,
#     298     on_error=on_error,
#     299 )
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:153, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     149 # pylint: disable=broad-except
#     150 # This function explicitly must deal with broad exceptions.
#     151 except Exception as exc:
#     152     # defer to shared logic for handling errors
# --> 153     _retry_error_helper(
#     154         exc,
#     155         deadline,
#     156         sleep,
#     157         error_list,
#     158         predicate,
#     159         on_error,
#     160         exception_factory,
#     161         timeout,
#     162     )
#     163     # if exception not raised, sleep before next attempt
#     164     time.sleep(sleep)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/retry/retry_base.py:212, in _retry_error_helper(exc, deadline, next_sleep, error_list, predicate_fn, on_error_fn, exc_factory_fn, original_timeout)
#     206 if not predicate_fn(exc):
#     207     final_exc, source_exc = exc_factory_fn(
#     208         error_list,
#     209         RetryFailureReason.NON_RETRYABLE_ERROR,
#     210         original_timeout,
#     211     )
# --> 212     raise final_exc from source_exc
#     213 if on_error_fn is not None:
#     214     on_error_fn(exc)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/api_core/retry/retry_unary.py:144, in retry_target(target, predicate, sleep_generator, timeout, on_error, exception_factory, **kwargs)
#     142 for sleep in sleep_generator:
#     143     try:
# --> 144         result = target()
#     145         if inspect.isawaitable(result):
#     146             warnings.warn(_ASYNC_RETRY_WARNING)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/cloud/_http/__init__.py:482, in JSONConnection.api_request(self, method, path, query_params, data, content_type, headers, api_base_url, api_version, expect_json, _target_object, timeout, extra_api_info)
#     479     data = json.dumps(data)
#     480     content_type = "application/json"
# --> 482 response = self._make_request(
#     483     method=method,
#     484     url=url,
#     485     data=data,
#     486     content_type=content_type,
#     487     headers=headers,
#     488     target_object=_target_object,
#     489     timeout=timeout,
#     490     extra_api_info=extra_api_info,
#     491 )
#     493 if not 200 <= response.status_code < 300:
#     494     raise exceptions.from_http_response(response)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/cloud/_http/__init__.py:341, in JSONConnection._make_request(self, method, url, data, content_type, headers, target_object, timeout, extra_api_info)
#     338     headers[CLIENT_INFO_HEADER] = self.user_agent
#     339 headers["User-Agent"] = self.user_agent
# --> 341 return self._do_request(
#     342     method, url, headers, data, target_object, timeout=timeout
#     343 )
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/cloud/_http/__init__.py:379, in JSONConnection._do_request(self, method, url, headers, data, target_object, timeout)
#     345 def _do_request(
#     346     self, method, url, headers, data, target_object, timeout=_DEFAULT_TIMEOUT
#     347 ):  # pylint: disable=unused-argument
#     348     """Low-level helper:  perform the actual API request over HTTP.
#     349
#     350     Allows batch context managers to override and defer a request.
#    (...)
#     377     :returns: The HTTP response.
#     378     """
# --> 379     return self.http.request(
#     380         url=url, method=method, headers=headers, data=data, timeout=timeout
#     381     )
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/auth/transport/requests.py:534, in AuthorizedSession.request(self, method, url, data, headers, max_allowed_time, timeout, **kwargs)
#     531 remaining_time = max_allowed_time
#     533 with TimeoutGuard(remaining_time) as guard:
# --> 534     self.credentials.before_request(auth_request, method, url, request_headers)
#     535 remaining_time = guard.remaining_timeout
#     537 with TimeoutGuard(remaining_time) as guard:
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/auth/credentials.py:230, in Credentials.before_request(self, request, method, url, headers)
#     228     self._non_blocking_refresh(request)
#     229 else:
# --> 230     self._blocking_refresh(request)
#     232 metrics.add_metric_header(headers, self._metric_header_for_usage())
#     233 self.apply(headers)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/auth/credentials.py:193, in Credentials._blocking_refresh(self, request)
#     191 def _blocking_refresh(self, request):
#     192     if not self.valid:
# --> 193         self.refresh(request)
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/oauth2/service_account.py:446, in Credentials.refresh(self, request)
#     444 else:
#     445     assertion = self._make_authorization_grant_assertion()
# --> 446     access_token, expiry, _ = _client.jwt_grant(
#     447         request, self._token_uri, assertion
#     448     )
#     449     self.token = access_token
#     450     self.expiry = expiry
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/oauth2/_client.py:304, in jwt_grant(request, token_uri, assertion, can_retry)
#     280 """Implements the JWT Profile for OAuth 2.0 Authorization Grants.
#     281
#     282 For more details, see `rfc7523 section 4`_.
#    (...)
#     300 .. _rfc7523 section 4: https://tools.ietf.org/html/rfc7523#section-4
#     301 """
#     302 body = {"assertion": assertion, "grant_type": _JWT_GRANT_TYPE}
# --> 304 response_data = _token_endpoint_request(
#     305     request,
#     306     token_uri,
#     307     body,
#     308     can_retry=can_retry,
#     309     headers={
#     310         metrics.API_CLIENT_HEADER: metrics.token_request_access_token_sa_assertion()
#     311     },
#     312 )
#     314 try:
#     315     access_token = response_data["access_token"]
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/oauth2/_client.py:275, in _token_endpoint_request(request, token_uri, body, access_token, use_json, can_retry, headers, **kwargs)
#     264 response_status_ok, response_data, retryable_error = _token_endpoint_request_no_throw(
#     265     request,
#     266     token_uri,
#    (...)
#     272     **kwargs
#     273 )
#     274 if not response_status_ok:
# --> 275     _handle_error_response(response_data, retryable_error)
#     276 return response_data
#
# File ~/git/obar1/0to100.kaggle.git/https§§§www.kaggle.com§learn§python/.venv/lib/python3.10/site-packages/google/oauth2/_client.py:68, in _handle_error_response(response_data, retryable_error)
#      65 except (KeyError, ValueError):
#      66     error_details = json.dumps(response_data)
# ---> 68 raise exceptions.RefreshError(
#      69     error_details, response_data, retryable=retryable_error
#      70 )
#
# RefreshError: ('invalid_grant: Invalid JWT: Token must be a short-lived token (60 minutes) and in a reasonable timeframe. Check your iat and exp values in the JWT claim.', {'error': 'invalid_grant', 'error_description': 'Invalid JWT: Token must be a short-lived token (60 minutes) and in a reasonable timeframe. Check your iat and exp values in the JWT claim.'})

# %% [markdown]
# ![alt text](image-2.png)

# %%
# Print information on all the columns in the "full" table in the "hacker_news" dataset
table.schema
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 2
#       1 # Print information on all the columns in the "full" table in the "hacker_news" dataset
# ----> 2 table.schema
#
# NameError: name 'table' is not defined

# %% [markdown]
# Each SchemaField tells us about a specific column (which we also refer to as a field). In order, the information is:
#
# The name of the column
# The field type (or datatype) in the column
# The mode of the column ('NULLABLE' means that a column allows NULL values, and is the default)
# A description of the data in that column
# The first field has the SchemaField:
#
# SchemaField('by', 'string', 'NULLABLE', "The username of the item's author.",())

# %%
# Preview the first five lines of the "full" table
client.list_rows(table, max_results=5).to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 # Preview the first five lines of the "full" table
# ----> 2 client.list_rows(table, max_results=5).to_dataframe()
#
# NameError: name 'table' is not defined
