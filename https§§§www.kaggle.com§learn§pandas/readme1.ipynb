# %% [markdown]
# # Indexing, Selecting & Assigning
# Pro data scientists do this dozens of times a day. You can, too!

# %%
import pandas as pd
reviews = pd.read_csv("./https§§§www.kaggle.com§learn§pandas/winemag-data-130k-v2.csv", index_col=0)
pd.set_option('display.max_rows', 5)
reviews
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 1    Portugal  This is ripe and fruity, a wine that is smooth...
# ..        ...                                                ...
# 500     Spain  Aromas of watermelon and a dusting of natural ...
# 501        US  A Verdelho with a taste of nuts—like Marcona a...
#
#               designation  points  price           province region_1  \
# 0            Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna
# 1                Avidagos      87   15.0              Douro      NaN
# ..                    ...     ...    ...                ...      ...
# 500                Rosado      87   11.0     Northern Spain    Rioja
# 501  Silvaspoons Vineyard      87   15.0         California     Lodi
#
#            region_2        taster_name taster_twitter_handle  \
# 0               NaN      Kerin O’Keefe          @kerinokeefe
# 1               NaN         Roger Voss            @vossroger
# ..              ...                ...                   ...
# 500             NaN  Michael Schachner           @wineschach
# 501  Central Valley     Virginie Boone               @vboone
#
#                                                  title         variety  \
# 0                    Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1        Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ..                                                 ...             ...
# 500                   El Coto 2011 Rosado Rosé (Rioja)            Rosé
# 501  Fenestra 2010 Silvaspoons Vineyard Verdelho (L...        Verdelho
#
#                   winery
# 0                Nicosia
# 1    Quinta dos Avidagos
# ..                   ...
# 500              El Coto
# 501             Fenestra
#
# [502 rows x 13 columns]

# %%
reviews.country
# Out:
# 0         Italy
# 1      Portugal
#          ...
# 500       Spain
# 501          US
# Name: country, Length: 502, dtype: object

# %%
reviews['country']
# Out:
# 0         Italy
# 1      Portugal
#          ...
# 500       Spain
# 501          US
# Name: country, Length: 502, dtype: object

# %% [markdown]
# ## Indexing in pandas¶

# %%
# To select the first row of data in a DataFrame, we may use the following:

reviews.iloc[0]
# Out:
# country                                                    Italy
# description    Aromas include tropical fruit, broom, brimston...
#                                      ...
# variety                                              White Blend
# winery                                                   Nicosia
# Name: 0, Length: 13, dtype: object

# %%
# To get a column with iloc, we can do the following:
reviews.iloc[:, 0]
# Out:
# 0         Italy
# 1      Portugal
#          ...
# 500       Spain
# 501          US
# Name: country, Length: 502, dtype: object

# %%
# Label-based selection¶
reviews.loc[:, 'country']
# Out:
# 0         Italy
# 1      Portugal
#          ...
# 500       Spain
# 501          US
# Name: country, Length: 502, dtype: object

# %%
reviews.set_index("country")
reviews
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 1    Portugal  This is ripe and fruity, a wine that is smooth...
# ..        ...                                                ...
# 500     Spain  Aromas of watermelon and a dusting of natural ...
# 501        US  A Verdelho with a taste of nuts—like Marcona a...
#
#               designation  points  price           province region_1  \
# 0            Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna
# 1                Avidagos      87   15.0              Douro      NaN
# ..                    ...     ...    ...                ...      ...
# 500                Rosado      87   11.0     Northern Spain    Rioja
# 501  Silvaspoons Vineyard      87   15.0         California     Lodi
#
#            region_2        taster_name taster_twitter_handle  \
# 0               NaN      Kerin O’Keefe          @kerinokeefe
# 1               NaN         Roger Voss            @vossroger
# ..              ...                ...                   ...
# 500             NaN  Michael Schachner           @wineschach
# 501  Central Valley     Virginie Boone               @vboone
#
#                                                  title         variety  \
# 0                    Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1        Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ..                                                 ...             ...
# 500                   El Coto 2011 Rosado Rosé (Rioja)            Rosé
# 501  Fenestra 2010 Silvaspoons Vineyard Verdelho (L...        Verdelho
#
#                   winery
# 0                Nicosia
# 1    Quinta dos Avidagos
# ..                   ...
# 500              El Coto
# 501             Fenestra
#
# [502 rows x 13 columns]

# %%
# Conditional selection¶
reviews.country == 'Italy'

# This operation produced a Series of True/False booleans based on the country of each record.
# Out:
# 0       True
# 1      False
#        ...
# 500    False
# 501    False
# Name: country, Length: 502, dtype: bool

# %%
reviews.loc[reviews.country == 'Italy']
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 6     Italy  Here's a bright, informal red that opens with ...       Belsito
# ..      ...                                                ...           ...
# 488   Italy  Pinot Grigio from the Friuli Grave tends to sh...           NaN
# 489   Italy  This bright white is redolent of tomato leaf, ...           NaN
#
#      points  price            province      region_1 region_2    taster_name  \
# 0        87    NaN   Sicily & Sardinia          Etna      NaN  Kerin O’Keefe
# 6        87   16.0   Sicily & Sardinia      Vittoria      NaN  Kerin O’Keefe
# ..      ...    ...                 ...           ...      ...            ...
# 488      87   18.0  Northeastern Italy  Friuli Grave      NaN            NaN
# 489      87   13.0  Northeastern Italy  Friuli Grave      NaN            NaN
#
#     taster_twitter_handle                                              title  \
# 0            @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 6            @kerinokeefe   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# ..                    ...                                                ...
# 488                   NaN  Vigneti Le Monde 2010 Pinot Grigio (Friuli Grave)
# 489                   NaN     Vigneti Le Monde 2010 Sauvignon (Friuli Grave)
#
#           variety            winery
# 0     White Blend           Nicosia
# 6        Frappato   Terre di Giurfo
# ..            ...               ...
# 488  Pinot Grigio  Vigneti Le Monde
# 489     Sauvignon  Vigneti Le Monde
#
# [120 rows x 13 columns]

# %%
reviews.loc[(reviews.country == 'Italy') | ('espresso' in reviews.designation )]
# Out:
#     country                                        description   designation  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...  Vulkà Bianco
# 6     Italy  Here's a bright, informal red that opens with ...       Belsito
# ..      ...                                                ...           ...
# 488   Italy  Pinot Grigio from the Friuli Grave tends to sh...           NaN
# 489   Italy  This bright white is redolent of tomato leaf, ...           NaN
#
#      points  price            province      region_1 region_2    taster_name  \
# 0        87    NaN   Sicily & Sardinia          Etna      NaN  Kerin O’Keefe
# 6        87   16.0   Sicily & Sardinia      Vittoria      NaN  Kerin O’Keefe
# ..      ...    ...                 ...           ...      ...            ...
# 488      87   18.0  Northeastern Italy  Friuli Grave      NaN            NaN
# 489      87   13.0  Northeastern Italy  Friuli Grave      NaN            NaN
#
#     taster_twitter_handle                                              title  \
# 0            @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 6            @kerinokeefe   Terre di Giurfo 2013 Belsito Frappato (Vittoria)
# ..                    ...                                                ...
# 488                   NaN  Vigneti Le Monde 2010 Pinot Grigio (Friuli Grave)
# 489                   NaN     Vigneti Le Monde 2010 Sauvignon (Friuli Grave)
#
#           variety            winery
# 0     White Blend           Nicosia
# 6        Frappato   Terre di Giurfo
# ..            ...               ...
# 488  Pinot Grigio  Vigneti Le Monde
# 489     Sauvignon  Vigneti Le Monde
#
# [120 rows x 13 columns]

# %%
reviews.loc[reviews.country.isin(['Italy', 'France'])]
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 6     Italy  Here's a bright, informal red that opens with ...
# ..      ...                                                ...
# 489   Italy  This bright white is redolent of tomato leaf, ...
# 499  France  This is a big, spicy wine, with very ripe flav...
#
#               designation  points  price            province  \
# 0            Vulkà Bianco      87    NaN   Sicily & Sardinia
# 6                 Belsito      87   16.0   Sicily & Sardinia
# ..                    ...     ...    ...                 ...
# 489                   NaN      87   13.0  Northeastern Italy
# 499  L'Esprit de Provence      87   20.0            Provence
#
#               region_1 region_2    taster_name taster_twitter_handle  \
# 0                 Etna      NaN  Kerin O’Keefe          @kerinokeefe
# 6             Vittoria      NaN  Kerin O’Keefe          @kerinokeefe
# ..                 ...      ...            ...                   ...
# 489       Friuli Grave      NaN            NaN                   NaN
# 499  Côtes de Provence      NaN     Roger Voss            @vossroger
#
#                                                  title      variety  \
# 0                    Nicosia 2013 Vulkà Bianco  (Etna)  White Blend
# 6     Terre di Giurfo 2013 Belsito Frappato (Vittoria)     Frappato
# ..                                                 ...          ...
# 489     Vigneti Le Monde 2010 Sauvignon (Friuli Grave)    Sauvignon
# 499  Domaine du Grand Cros 2011 L'Esprit de Provenc...         Rosé
#
#                     winery
# 0                  Nicosia
# 6          Terre di Giurfo
# ..                     ...
# 489       Vigneti Le Monde
# 499  Domaine du Grand Cros
#
# [186 rows x 13 columns]

# %%
reviews.loc[reviews.description.notnull()]
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 1    Portugal  This is ripe and fruity, a wine that is smooth...
# ..        ...                                                ...
# 500     Spain  Aromas of watermelon and a dusting of natural ...
# 501        US  A Verdelho with a taste of nuts—like Marcona a...
#
#               designation  points  price           province region_1  \
# 0            Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna
# 1                Avidagos      87   15.0              Douro      NaN
# ..                    ...     ...    ...                ...      ...
# 500                Rosado      87   11.0     Northern Spain    Rioja
# 501  Silvaspoons Vineyard      87   15.0         California     Lodi
#
#            region_2        taster_name taster_twitter_handle  \
# 0               NaN      Kerin O’Keefe          @kerinokeefe
# 1               NaN         Roger Voss            @vossroger
# ..              ...                ...                   ...
# 500             NaN  Michael Schachner           @wineschach
# 501  Central Valley     Virginie Boone               @vboone
#
#                                                  title         variety  \
# 0                    Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1        Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ..                                                 ...             ...
# 500                   El Coto 2011 Rosado Rosé (Rioja)            Rosé
# 501  Fenestra 2010 Silvaspoons Vineyard Verdelho (L...        Verdelho
#
#                   winery
# 0                Nicosia
# 1    Quinta dos Avidagos
# ..                   ...
# 500              El Coto
# 501             Fenestra
#
# [502 rows x 13 columns]

# %%
# Assigning data¶
reviews['critic'] = 'everyone'
reviews
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 1    Portugal  This is ripe and fruity, a wine that is smooth...
# ..        ...                                                ...
# 500     Spain  Aromas of watermelon and a dusting of natural ...
# 501        US  A Verdelho with a taste of nuts—like Marcona a...
#
#               designation  points  price           province region_1  \
# 0            Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna
# 1                Avidagos      87   15.0              Douro      NaN
# ..                    ...     ...    ...                ...      ...
# 500                Rosado      87   11.0     Northern Spain    Rioja
# 501  Silvaspoons Vineyard      87   15.0         California     Lodi
#
#            region_2        taster_name taster_twitter_handle  \
# 0               NaN      Kerin O’Keefe          @kerinokeefe
# 1               NaN         Roger Voss            @vossroger
# ..              ...                ...                   ...
# 500             NaN  Michael Schachner           @wineschach
# 501  Central Valley     Virginie Boone               @vboone
#
#                                                  title         variety  \
# 0                    Nicosia 2013 Vulkà Bianco  (Etna)     White Blend
# 1        Quinta dos Avidagos 2011 Avidagos Red (Douro)  Portuguese Red
# ..                                                 ...             ...
# 500                   El Coto 2011 Rosado Rosé (Rioja)            Rosé
# 501  Fenestra 2010 Silvaspoons Vineyard Verdelho (L...        Verdelho
#
#                   winery    critic
# 0                Nicosia  everyone
# 1    Quinta dos Avidagos  everyone
# ..                   ...       ...
# 500              El Coto  everyone
# 501             Fenestra  everyone
#
# [502 rows x 14 columns]
