# %% [markdown]
# # Renaming and Combining

# %%
import pandas as pd
pd.set_option('display.max_rows', 5)
import numpy as np
reviews = pd.read_csv("https§§§www.kaggle.com§learn§pandas/winemag-data-130k-v2.csv", index_col=0)

# %%
reviews.rename(columns={'points': 'score'})
# Out:
#       country                                        description  \
# 0       Italy  Aromas include tropical fruit, broom, brimston...
# 1    Portugal  This is ripe and fruity, a wine that is smooth...
# ..        ...                                                ...
# 500     Spain  Aromas of watermelon and a dusting of natural ...
# 501        US  A Verdelho with a taste of nuts—like Marcona a...
#
#               designation  score  price           province region_1  \
# 0            Vulkà Bianco     87    NaN  Sicily & Sardinia     Etna
# 1                Avidagos     87   15.0              Douro      NaN
# ..                    ...    ...    ...                ...      ...
# 500                Rosado     87   11.0     Northern Spain    Rioja
# 501  Silvaspoons Vineyard     87   15.0         California     Lodi
#
#            region_2        taster_name taster_twitter_handle  \
# 0               NaN      Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...               ...                                                ...
# 500             Spain  Aromas of watermelon and a dusting of natural ...
# 501                US  A Verdelho with a taste of nuts—like Marcona a...
#
#                       designation  points  price           province region_1  \
# firstEntry           Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna
# secondEntry              Avidagos      87   15.0              Douro      NaN
# ...                           ...     ...    ...                ...      ...
# 500                        Rosado      87   11.0     Northern Spain    Rioja
# 501          Silvaspoons Vineyard      87   15.0         California     Lodi
#
# ...

# %%
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 500        Spain  Aromas of watermelon and a dusting of natural ...
# 501           US  A Verdelho with a taste of nuts—like Marcona a...
#
# fields           designation  points  price           province region_1  \
# wines
# 0               Vulkà Bianco      87    NaN  Sicily & Sardinia     Etna
# 1                   Avidagos      87   15.0              Douro      NaN
# ...                      ...     ...    ...                ...      ...
# 500                   Rosado      87   11.0     Northern Spain    Rioja
# 501     Silvaspoons Vineyard      87   15.0         California     Lodi
#
# fields        region_2        taster_name taster_twitter_handle  \
# wines
# ...

# %% [markdown]
# ## Combining
#
# When performing operations on a dataset, we will sometimes need to combine different DataFrames and/or Series in non-trivial ways. Pandas has three core methods for doing this. In order of increasing complexity, these are concat(), join(), and merge(). Most of what merge() can do can also be done more simply with join(), so we will omit it and focus on the first two functions here.

# %%
p = 'https§§§www.kaggle.com§learn§pandas'
canadian_youtube = pd.read_csv(p+"/CAvideos.csv")
british_youtube = pd.read_csv(p+"/GBvideos.csv")

pd.concat([canadian_youtube, british_youtube])
# Out:
#         video_id trending_date                                       title  \
# 0    n1WpP7iowLc      17.14.11  Eminem - Walk On Water (Audio) ft. Beyoncé
# 1    0dBIkQ4Mz1M      17.14.11               PLUSH - Bad Unboxing Fan Mail
# ..           ...           ...                                         ...
# 997  CyzEtbG-sxY      17.18.11             [M/V] SEVENTEEN(세븐틴) - 박수(CLAP)
# 998  A_Z3AokMwWI      17.19.11               MINECON Earth 2017 Livestream
#
#     channel_title  category_id              publish_time  \
# 0      EminemVEVO           10  2017-11-10T17:00:03.000Z
# 1       iDubbbzTV           23  2017-11-13T17:00:00.000Z
# ..            ...          ...                       ...
# 997     SEVENTEEN           10  2017-11-06T09:00:00.000Z
# 998    TeamMojang           20  2017-11-18T19:12:51.000Z
#
#                                                   tags     views   likes  \
# 0    Eminem|"Walk"|"On"|"Water"|"Aftermath/Shady/In...  17158579  787425
# ...

# %%
left = canadian_youtube.set_index(['title', 'trending_date'])
right = british_youtube.set_index(['title', 'trending_date'])

left.join(right, lsuffix='_CAN', rsuffix='_UK').count()
# Out:
# video_id_CAN                 999
# channel_title_CAN            999
#                             ...
# video_error_or_removed_UK     60
# description_UK                60
# Length: 28, dtype: int64
